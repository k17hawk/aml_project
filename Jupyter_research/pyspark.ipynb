# %%
from pyspark.sql import SparkSession
spark_session =  SparkSession.builder\
    .master('local[*]')\
    .config("spark.driver.memory", "6g")\
    .appName('AML_project')\
    .getOrCreate()

# %%
train_df = spark_session.read.csv("training_data.csv")
test_df = spark_session.read.csv("testing_data.csv")

# %%
train_df.show()
# Out:
# +--------------+----------------+--------+----------------+-----------------+--------------------+--------------------+------------+---------------+----+-----+----+----+------+------+-------------+
# |           _c0|             _c1|     _c2|             _c3|              _c4|                 _c5|                 _c6|         _c7|            _c8| _c9| _c10|_c11|_c12|  _c13|  _c14|         _c15|
# +--------------+----------------+--------+----------------+-----------------+--------------------+--------------------+------------+---------------+----+-----+----+----+------+------+-------------+
# |Sender_account|Receiver_account|  Amount|Payment_currency|Received_currency|Sender_bank_location|Receiver_bank_loc...|Payment_type|Laundering_type|Year|Month| Day|Hour|Minute|Second|Is_laundering|
# |    8109671189|      8312632191|14871.11|              10|               10|                  16|                  16|           0|             13|2023|    8|  16|  23|     2|    27|            0|
# ...
